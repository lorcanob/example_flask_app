# %%
import os

import cv2
import matplotlib.pyplot as plt

from core.tongue_detector import TongueDetector

# %%
td = TongueDetector()
# Out:
# YOLOv5  2022-10-13 Python-3.8.13 torch-1.12.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...

# %%
BASE_PATH = os.path.abspath('')
image = cv2.imread(os.path.join(os.path.dirname(BASE_PATH), 'niigata_practise', '1_tongue', 'PICT0133.JPG'))
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# %%
td.image = image

# %%
results = td.infer()
# Out:
# image 1/1: 1560x2080 1 tongue
# Speed: 12.3ms pre-process, 539.4ms inference, 2.4ms NMS per image at shape (1, 3, 480, 640)
# Time elapsed: 0.59s

# %%
results.show()

# %%
td.model()

# %%
7*224
# Out:
# 1568

# %%
xmin = round(results.pandas().xyxy[0]['xmin'][0])
ymin = round(results.pandas().xyxy[0]['ymin'][0])
xmax = round(results.pandas().xyxy[0]['xmax'][0])
ymax = round(results.pandas().xyxy[0]['ymax'][0])

# %%
# %matplotlib inline

# %%
plt.imshow(image)

# %%
plt.imshow(image[ymin:ymax, xmin:xmax])

# %%
plt.imshow(cv2.resize(image[ymin:ymax, xmin:xmax], (200, 200)))

# %%
image[xmin:xmax, ymin:ymax]
# Out:
# (433, 1373, 3)
